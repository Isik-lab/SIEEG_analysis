# %% [markdown]
# # RSA

# %%
from glob import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.io import loadmat

# %%
subj = 'subj001'
subj_date = 'subj001_10062023'
data_path = '../data'
rdm_path = f'{data_path}/interim/PairwiseDecoding/{subj}'
annotation_file = f'{data_path}/raw/annotations/annotations.csv'
preproc_file = f'{data_path}/interim/SIdyads_EEG_pilot/{subj_date}/{subj_date}_preproc.mat'

# %% [markdown]
# ## Load RDM

# %% [markdown]
# The RDMs are saved separately for each iteration (of 20). Load the RDMs and average them. Then plot the average RDM across time. This visualization is a check of the data quality.

# %%
# files = sorted(glob(f'{rdm_path}/*.csv.gz'))
# rdm = []
# for f in files:
#     rdm.append(pd.read_csv(f))
# rdm = pd.concat(rdm)
# average_rdm = rdm.groupby(['v1', 'v2', 'time']).mean().reset_index()

# %%
# plotting_data = average_rdm.groupby('time').mean().reset_index()
# acc = plotting_data.accuracy.to_numpy()
# time = plotting_data.time.to_numpy()
# ymin, ymax = acc.min()-.01, acc.max()+.01

# %%
# _, ax = plt.subplots()
# sns.lineplot(x='time', y='accuracy', data=plotting_data, ax=ax)
# ax.set_xlabel('Time (s)')
# ax.set_ylabel('Decoding accuracy')
# ax.vlines(x=[0, 0.5], ymin=ymin, ymax=ymax,
#           colors='gray', linestyles='dashed', zorder=0)
# ax.hlines(y=.5, xmin=time.min(), xmax=time.max(),
#           colors='gray', linestyles='solid', zorder=0)
# ax.set_xlim([time.min(), time.max()])
# ax.set_ylim([ymin, ymax])
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)
# ax.spines['bottom'].set_visible(False)

# %%
preproc = loadmat(preproc_file)
time = preproc['time'].squeeze()

# %%
rdm_path = f'{data_path}/interim/CleanedEEG/{subj}/correlation_rdm.npy'
neural_rdms = np.load(rdm_path).T
print(neural_rdms.shape)
# Out:
# (31125, 276)

# %% [markdown]
# ## Feature RDMs

# %% [markdown]
# Load the feature annotations and make the RDMs. Care needs to be paid to ensure that that the order of the vidoes across the two RDMs is consistent.

# %%
from scipy.spatial.distance import pdist, squareform

# %%
features_to_exclude = ['dominance', 'cooperation', 'intimacy']

# %%
df = pd.read_csv(annotation_file).set_index('video_name')
df = df.drop(columns=features_to_exclude)
df.head()
# Out:
#                                   indoor  expanse  transitivity  \
# video_name
# -YwZOeyAQC8_15.mp4                     1    0.225      0.895833
# 1AIVH5cEWrI_35.mp4                     1    0.250      0.104167
# 2-8-0-2-5-4-8-8-5028025488_7.mp4       1    0.275      1.000000
# 3PJaYWt0cws_5.mp4                      0    0.625      1.000000
# 7-5-1-0-3-6-9-8-3775103698_9.mp4       1    0.275      0.925000
#
#                                   agent distance  facingness  joint action  \
# video_name
# -YwZOeyAQC8_15.mp4                      0.000000    0.045455      0.700000
# 1AIVH5cEWrI_35.mp4                      0.075000    1.000000      0.825000
# 2-8-0-2-5-4-8-8-5028025488_7.mp4        0.045455    0.050000      0.575000
# 3PJaYWt0cws_5.mp4                       0.725000    0.340909      0.022727
# 7-5-1-0-3-6-9-8-3775103698_9.mp4        0.275000    0.636364      0.750000
#
#                                   communication   valence   arousal
# video_name
# -YwZOeyAQC8_15.mp4                        0.550  0.650000  0.340909
# 1AIVH5cEWrI_35.mp4                        0.900  0.675000  0.340909
# 2-8-0-2-5-4-8-8-5028025488_7.mp4          0.500  0.675000  0.075000
# 3PJaYWt0cws_5.mp4                         0.150  0.600000  0.400000
# 7-5-1-0-3-6-9-8-3775103698_9.mp4          0.825  0.722222  0.125000

# %%
feature_rdms = {}
for col in df.columns:
    arr = np.expand_dims(df[col].to_numpy(), axis=1)
    feature_rdms[col] = pdist(arr, metric='euclidean')

# %% [markdown]
# ## Correlate Features and EEG

# %%
from src.tools import corr

# %%
rsa = {}
for key, val in feature_rdms.items():
    time_corr = np.zeros(neural_rdms.shape[-1])
    for t in range(neural_rdms.shape[-1]):
        time_corr[t] = corr(val, neural_rdms[:, t])
    rsa[key] = time_corr

# %%
_, axes = plt.subplots(3,3)
axes = axes.flatten()
for ax, (key, val) in zip(axes, rsa.items()):
    ymin, ymax = val.min(), val.max()
    ax.plot(time, val, label=key)
    ax.set_xlabel('Time (s)')
    ax.set_ylabel('RSA')
    ax.vlines(x=[0, 0.5], ymin=ymin, ymax=ymax,
            colors='gray', linestyles='dashed', zorder=0)
    ax.hlines(y=0, xmin=time.min(), xmax=time.max(),
            colors='gray', linestyles='solid', zorder=0)
    ax.set_xlim([time.min(), time.max()])
    ax.set_ylim([ymin, ymax])
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.set_title(key)
plt.tight_layout()
